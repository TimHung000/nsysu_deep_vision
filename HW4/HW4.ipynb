# %% [markdown]
# # Neural Network for CIFAR10 Classification
# In this assignment, we will implement a two-layer fully-connected neural network for CIFAR10 classification.

# %% [markdown]
# ## Data Preparation and Visualization

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import sys
# sys.path.append('/content/drive/MyDrive/HW4/')
sys.path.append('./')

# %%
# You may change `MODEL_DIR` to a existing local directory if you are not using Colab
MODEL_DIR = './'
MODEL_PATH = MODEL_DIR + 'model.pt' if MODEL_DIR.endswith('/') else MODEL_DIR + '/model.pt'
MODEL_PATH1 = MODEL_DIR + 'model1.pt' if MODEL_DIR.endswith('/') else MODEL_DIR + '/model1.pt'

# %%
from _utils import load_data, Dataset, Dataloader, FCL_Tests, ReLU_Tests, SCE_Tests, plot_curves, plot_result
import numpy as np
import matplotlib.pyplot as plt
import random
import torch

# %%
if torch.cuda.is_available():
  DEVICE = 'cuda'
  print(f'Using torch {torch.__version__}, device = {torch.cuda.get_device_name(0)}')
else:
  DEVICE = 'cpu'
  print(f'Using torch {torch.__version__}, device = cpu')
# Out:
# Using torch 2.0.0+cu117, device = GeForce GTX 1050

# %%
images, labels, classes = load_data()
# Out:
# Files already downloaded and verified

# %%
print(f'Data type of images: {images.dtype} (value range: [{images.min()}, {images.max()}])')
print(f'Shape of images: {images.shape}')
print(f'Shape of labels: {labels.shape}')
print(f'Number of classes: {len(classes)}')
print(f'Classes: {classes}')
# Out:
# Data type of images: uint8 (value range: [0, 255])
# Shape of images: (50000, 32, 32, 3)
# Shape of labels: (50000,)
# Number of classes: 10
# Classes: ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# Display samples of each class
plt.rcParams['figure.figsize'] = (16, 16)
num_classes = len(classes)
num_example = 10
for label, class_name in enumerate(classes):
  idxs = np.flatnonzero(labels == label)
  idxs = np.random.choice(idxs, num_example, replace=False)
  for i, idx in enumerate(idxs):
    plt_idx = i * num_classes + label + 1
    plt.subplot(num_example, num_classes, plt_idx)
    plt.imshow(images[idx]); plt.axis('off')
    if i == 0:
      plt.title(class_name)
plt.show()

# %%
# Data splitting with numpy array slicing
num_data = images.shape[0]
split_ratio = {'train': 0.6, 'valid': 0.2, 'test': 0.2}
num_valid_data = round(num_data * split_ratio['valid'])
num_test_data = round(num_data * split_ratio['test'])
num_train_data = num_data - (num_valid_data + num_test_data)

start_idx = 0
train_dataset = Dataset(images[start_idx:start_idx+num_train_data], labels[start_idx:start_idx+num_train_data])
start_idx += num_train_data

valid_dataset = Dataset(images[start_idx:start_idx+num_valid_data], labels[start_idx:start_idx+num_valid_data])
start_idx += num_valid_data

test_dataset = Dataset(images[start_idx:start_idx+num_test_data], labels[start_idx:start_idx+num_test_data])

print(f'Number of training data: {len(train_dataset)}')
print(f'Number of validation data: {len(valid_dataset)}')
print(f'Number of test data: {len(test_dataset)}')
# Out:
# Number of training data: 30000
# Number of validation data: 10000
# Number of test data: 10000

# %% [markdown]
# ## Layer Definition
# The architecture of our two-layer fully-connected neural network is like:
#
# Input $\rightarrow$ Fully-Connected Layer1 $\rightarrow$ ReLU  $\rightarrow$ Fully-Connected Layer2 $\rightarrow$ Softmax
#
# The learnable parameters are weights and bias of the two fully-connected layers. Let's name and clarify the parameters and their shapes:
#
# 1. Input data: $\mathbf{x}$, shape: ${N\times D}$
# 2. Weights of first fully-connected layer: $\mathbf{w_1}$, shape: ${D\times H}$
# 3. Bias of first fully-connected layer: $\mathbf{b_1}$, shape: ${H}$
# 4. Weights of second fully-connected layer: $\mathbf{w_2}$, shape: ${H\times C}$
# 5. Bias of second fully-connected layer: $\mathbf{b_2}$, shape: ${C}$
# 6. Output of the network: $\mathbf{S}$, shape: ${N\times C}$
#
# And then we can simply express the function of our network by:
# $$\mathbf{S} = \mathbf{w_2} * ReLU(\mathbf{w_1} * \mathbf{x} + \mathbf{b_1}) + \mathbf{b_2}$$
#
# Since the two fully-connected layers do the same job, that is, multiply weights with input and then plus bias, we define a class called FullyConnectedLayer to implement a single fully-connected layer.

# %%
class FullyConnectedLayer(object):
  def __init__(self, device='cpu'):
    self.dv = device
  def forward(self, x, w, b):
    N, D = x.shape # (batch_size, input_size)
    Dw, F = w.shape # (input_size, output_size)
    assert Dw == D, f'Wrong shape of weights, expected ({D},{F}) but got ({Dw},{F})'
    Fb = b.shape[0] # (output_size,)
    assert Fb == F, f'Wrong shape of bias, expected ({F},) but got ({Fb},)'
    out = torch.zeros((N, F)).to(self.dv)
    ####################
    # TODO:
    # 1. Implement fully connected layer with `w` * `x` + `b` and store the result in variable `out`
    ####################
    # -----START OF YOUR CODE-----
    out = torch.matmul(x, w) + b #(batch_size, output_size)
    # ------END OF YOUR CODE------
    self.cache = (x, w, b, out)
    return out
  def backward(self, backprop):
    N, F = backprop.shape
    dw = None
    db = None
    ####################
    # TODO:
    # 1. Derive the gradient of bias, i.e., d(out)/d(b)
    # 2. Multiply d(out)/d(b) with `backprop` due to chain rule, and then store the AVERAGED result in variable `db`
    # 3. Then, derive the gradient of weights, i.e., d(out)/d(w)
    # 4. Multiply d(out)/d(w) with `backprop` due to chain rule, and then store the AVERAGED result in variable `dw`
    # HINT: Shapes of `db` and `dw` should be (F,) and (D, F) respectively
    ####################
    # -----START OF YOUR CODE-----
    dw = torch.matmul(self.cache[0].transpose(0, 1) , backprop) / self.cache[0].shape[0]

    db = torch.sum(backprop , axis=0, keepdim=False) / self.cache[0].shape[0]
    # ------END OF YOUR CODE------
    return dw, db

# %%
layer = FullyConnectedLayer()
FCL_Tests(layer)
# Out:
# Results of fully connected layer forward and backward tests: All passed.

# %% [markdown]
# ReLU (Rectified Linear Unit) is the currently most used non-linearity (or called activation function) in neural networks. Its formula as following:
# $$ReLU(t) = max(0, t)$$
#
# Since ReLU only allows positive values to be passed forward, any negative values of the input will not be able to propagate gradients during backpropagation.

# %%
class ReLU(object):
  def __init__(self):
    pass
  def forward(self, t):
    out = t.clone()
    ####################
    # TODO:
    # 1. Implement ReLU on `t` and store in variable `out`
    ####################
    # -----START OF YOUR CODE-----
    out = torch.maximum(torch.zeros_like(out), out)
    # ------END OF YOUR CODE------
    self.cache = (t, out)
    return out
  def backward(self, backprop):
    dt = torch.zeros_like(backprop)
    ####################
    # TODO:
    # 1. Derive d(out)/d(t)
    # 2. Multiply d(out)/d(t) with `backprop` due to chain rule, and then store the result in variable `dt`
    ####################
    # -----START OF YOUR CODE-----
    dt = self.cache[1]
    dt[dt > 0] = 1
    dt = dt.mul(backprop)
    # ------END OF YOUR CODE------
    return dt

# %%
layer = ReLU()
ReLU_Tests(layer)
# Out:
# Results of ReLU function tests: All passed.

# %% [markdown]
# Softmax is used to convert a vector of real numbers into a probability distribution over classes. It can be expressed mathematically as:
# $$softmax(\mathbf{S}_i)=\mathbf{p}_i=\frac{exp(\mathbf{S}_i)}{\sum_{j=1}^\mathbf{C}exp(\mathbf{S}_j)}$$
# And the cross-entropy loss, on the other hand, is a measure of the difference between the predicted probability distribution and the true probability distribution of the labels. Let $\mathbf{y}$ be **one-hot encoded** ground-truth label, that is, its shape would be the same with output of the network. Cross-entropy loss formula is defined as:
# $$CE = -\sum\mathbf{y}_i * log(\mathbf{p}_i)$$

# %%
class Softmax_CrossEntropy(object):
  def __init__(self):
    pass
  def forward(self, y, net_out):
    N, F = net_out.shape
    prob = torch.zeros_like(net_out)
    ####################
    # TODO:
    # 1. Implement Softmax and store the result in variable `prob`
    # HINT: Shape of `prob` should be (N, F)
    ####################
    # -----START OF YOUR CODE-----
    # Subtract the maximum logit to improve numerical stability
    # exp_logits: matrix of shape (batch_size, num_classes)
    exp_logits = torch.exp(net_out - torch.max(net_out, axis=1, keepdims=True)[0])
    # Compute the softmax probabilities
    # softmax_probs: matrix of shape (batch_size, num_classes)    
    softmax_probs = exp_logits / torch.sum(exp_logits, axis=1, keepdims=True)
    prob = softmax_probs
    # ------END OF YOUR CODE------
    self.cache = (y, prob)
    pred_y = prob.argmax(dim=1)
    y_one_hot = torch.zeros_like(net_out)
    y_one_hot[np.arange(N), y] = 1
    loss = torch.zeros(1)
    ####################
    # TODO:
    # 1. Implement cross-entropy loss and store the result in variable `loss`
    ####################
    # -----START OF YOUR CODE-----
    # Compute the cross-entropy loss
    loss = -torch.mean(torch.sum(y_one_hot * torch.log(prob), axis=1))

    # ------END OF YOUR CODE------
    return pred_y, loss
  def backward(self):
    y, grad = self.cache
    N, F = grad.shape
    ####################
    # TODO:
    # 1. Derive the gradient of `net_out` and store the result in variable `grad`
    ####################
    # -----START OF YOUR CODE-----

    # Compute the gradient of the cross-entropy loss with respect to the logits
    # logits_grad: matrix of shape (batch_size, num_classes)
    y_one_hot = torch.zeros_like(grad)
    y_one_hot[np.arange(N), y] = 1
    grad = (grad - y_one_hot) / y_one_hot.shape[0]
    
    # ------END OF YOUR CODE------
    return grad

# %%
layer = Softmax_CrossEntropy()
SCE_Tests(layer)
# Out:
# Results of softmax and cross entropy forward and backward tests: All passed.

# %% [markdown]
# ## Network Definition

# %%
class Classifier(object):
  def __init__(self, dim_in, dim_hidden, dim_out, device='cpu'):
    self.dv = device
    np.random.seed(0)
    self.params = {'w1': torch.from_numpy(np.random.randn(dim_in, dim_hidden)*0.8).to(self.dv),
             'b1': torch.zeros(dim_hidden).to(self.dv),
             'w2': torch.from_numpy(np.random.randn(dim_hidden, dim_out)*0.8).to(self.dv),
             'b2': torch.zeros(dim_out).to(self.dv)}
    layer1 = FullyConnectedLayer()
    activation = ReLU()
    layer2 = FullyConnectedLayer()
    self.net = [layer1, activation, layer2]
    self.loss_func = Softmax_CrossEntropy()
    
  def save_model(self, path):
    torch.save(self.params, path)

  def load_model(self, path):
    checkpoint = torch.load(path, map_location=self.dv)
    self.params = checkpoint

  def training(self, train_dataloader, valid_dataloader, epochs=200, learning_rate=1e-3, learning_rate_decay=0.95, verbose=1):
    print(f'Training with batch_size={train_dataloader[0][0].shape[0]}, hidden_dim={self.params["w1"].shape[1]}, learning_rate={learning_rate}, learning_rate_decay={learning_rate_decay}')
    train_loss_log = []
    train_acc_log = []
    valid_loss_log = []
    valid_acc_log = []
    best_val_loss = None
    for epoch in range(epochs):
      if verbose > 0 and (epoch+1) % verbose == 0:
        print(f'Epoch {epoch+1}:')
      single_epoch_log = ''
      train_loss = 0.0
      train_corr = 0.0; train_eval = 0.0
      for batch_idx in range(len(train_dataloader)):
        ### Model Input and Loss Calculation ###
        batch_data = train_dataloader[batch_idx]
        batch_img, batch_label = batch_data
        layer1_out = self.net[0].forward(torch.from_numpy(batch_img).to(self.dv), self.params['w1'], self.params['b1'])
        layer1_out = self.net[1].forward(layer1_out)
        layer2_out = self.net[2].forward(layer1_out, self.params['w2'], self.params['b2'])
        pred_y, loss = self.loss_func.forward(batch_label, layer2_out)
        train_loss += loss.cpu().numpy()
        train_corr += torch.count_nonzero(pred_y == torch.from_numpy(batch_label).to(self.dv)).cpu().numpy()
        train_eval += batch_img.shape[0]
        ### Backpropagation and Optimization ###
        params_grad = {}
        dloss_dout2 = self.loss_func.backward()
        dout2_dw2, dout2_db2 = self.net[2].backward(dloss_dout2)
        params_grad['w2'] = dout2_dw2; params_grad['b2'] = dout2_db2
        dout2_dout1 = self.net[1].backward(dloss_dout2.mm(self.params['w2'].T))
        dout1_dw1, dout1_db1 = self.net[0].backward(dout2_dout1)
        params_grad['w1'] = dout1_dw1; params_grad['b1'] = dout1_db1
        ####################
        # TODO:
        # 1. Update model parameters, i.e., `self.params`, by gradient descent
        ####################
        # -----START OF YOUR CODE-----
        self.params['w1'] = self.params['w1'] - learning_rate * params_grad['w1']
        self.params['b1'] = self.params['b1'] - learning_rate * params_grad['b1']
        self.params['w2'] = self.params['w2'] - learning_rate * params_grad['w2']
        self.params['b2'] = self.params['b2'] - learning_rate * params_grad['b2']
        
        # ------END OF YOUR CODE------
      train_loss_log.append(train_loss/train_eval)
      train_acc_log.append(100*train_corr/train_eval)
      single_epoch_log += f'Training accuracy: {format(train_acc_log[-1], ".2f")}%, loss: {format(train_loss_log[-1], ".4f")}\n'
      train_dataloader.shuffle()

      valid_loss = 0.0
      valid_corr = 0.0; valid_eval = 0.0
      for batch_idx in range(len(valid_dataloader)):
        ### Model Input and Loss Calculation ###
        batch_data = valid_dataloader[batch_idx]
        batch_img, batch_label = batch_data
        layer1_out = self.net[0].forward(torch.from_numpy(batch_img).to(self.dv), self.params['w1'], self.params['b1'])
        layer1_out = self.net[1].forward(layer1_out)
        layer2_out = self.net[2].forward(layer1_out, self.params['w2'], self.params['b2'])
        pred_y, loss = self.loss_func.forward(batch_label, layer2_out)
        valid_loss += loss.cpu().numpy()
        valid_corr += torch.count_nonzero(pred_y == torch.from_numpy(batch_label).to(self.dv)).cpu().numpy()
        valid_eval += batch_img.shape[0]
      valid_loss_log.append(valid_loss/valid_eval)
      valid_acc_log.append(100*valid_corr/valid_eval)
      single_epoch_log += f'Validaion accuracy: {format(valid_acc_log[-1], ".2f")}%, loss: {format(valid_loss_log[-1], ".4f")}'
      if best_val_loss is None or valid_loss < best_val_loss:
        best_val_loss = valid_loss
        self.save_model(MODEL_PATH)
        if verbose == 1:
          single_epoch_log = '[MODEL SAVED]\n' + single_epoch_log
      if verbose > 0 and (epoch+1) % verbose == 0:
        print(single_epoch_log)
      learning_rate *= learning_rate_decay # update learning_rate every epoch
    return train_loss_log,train_acc_log,valid_loss_log,valid_acc_log

  def test(self, test_dataloader):
    total_corr = 0; total_eval = 0
    for batch_idx in range(len(test_dataloader)):
      ### Model Input ###
      batch_data = test_dataloader[batch_idx]
      batch_img, batch_label = batch_data
      layer1_out = self.net[0].forward(torch.from_numpy(batch_img).to(self.dv), self.params['w1'], self.params['b1'])
      layer1_out = self.net[1].forward(layer1_out)
      layer2_out = self.net[2].forward(layer1_out, self.params['w2'], self.params['b2'])
      pred_y, _ = self.loss_func.forward(batch_label, layer2_out)
      total_corr += torch.count_nonzero(pred_y == torch.from_numpy(batch_label).to(self.dv)).cpu().numpy()
      total_eval += batch_img.shape[0]
    print(f'Got {total_corr} correct prediction in {total_eval} test data, accuracy: {format((total_corr*1.0/total_eval)*100, ".2f")}%')

# %% [markdown]
# ## Searching for Best Hyperparameters
# Hyperparameters are configuration variables that set by users before model training. They influence the learning process and the final performance of the model. The goal of selecting optimal hyperparameters is to improve the model's accuracy and generalization ability.
#
# Hyperparameters in this assignment include hidden layer size, batch size, learning rate, and learning rate decay. You may change candidate values of them in the following cells and observe which might be useful to optimize the model. Howerver,  as running the whole section may take a while, you are allowed to not running all of the cells.

# %%
# Configurations
IN_DIM = np.prod(images[0].shape)
OUT_DIM = len(classes)

# %%
# Hyperparameters
EPOCHS = 80
BATCH_SIZE = 16
LR = 1e-3
LR_DECAY = 0.95
HIDEEN_DIM = 64

# %%
lr_cand = [1e-2, 1e-3, 1e-4]
train_acc = []
valid_acc = []

# Classifier
print(f'---Classifier---')
for lr in lr_cand:
  train_dataloader = Dataloader(train_dataset, batch_size=BATCH_SIZE)
  valid_dataloader = Dataloader(valid_dataset, batch_size=BATCH_SIZE)
  model = Classifier(IN_DIM, HIDEEN_DIM, OUT_DIM)
  _, ta, _, va = model.training(train_dataloader, valid_dataloader, epochs=EPOCHS, learning_rate=lr, learning_rate_decay=LR_DECAY, verbose=0)
  train_acc.append(ta); valid_acc.append(va)

plot_curves(lr_cand, train_acc, valid_acc)
# Out:
# ---Classifier---
# Training with batch_size=16, hidden_dim=64, learning_rate=0.01, learning_rate_decay=0.95
# Training with batch_size=16, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.95
# Training with batch_size=16, hidden_dim=64, learning_rate=0.0001, learning_rate_decay=0.95

# %%
bs_cand = [8, 16, 100]
train_acc = []
valid_acc = []

# Classifier
print(f'---Classifier---')
for bs in bs_cand:
  train_dataloader = Dataloader(train_dataset, batch_size=bs)
  valid_dataloader = Dataloader(valid_dataset, batch_size=bs)
  model = Classifier(IN_DIM, HIDEEN_DIM, OUT_DIM, device=DEVICE)
  _, ta, _, va = model.training(train_dataloader, valid_dataloader, epochs=EPOCHS, learning_rate=LR, learning_rate_decay=LR_DECAY, verbose=0)
  train_acc.append(ta); valid_acc.append(va)

plot_curves(bs_cand, train_acc, valid_acc)
# Out:
# ---Classifier---
# Training with batch_size=8, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.95
# Training with batch_size=16, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.95
# Training with batch_size=100, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.95

# %%
hd_cand = [32, 64, 256]
train_acc = []
valid_acc = []

# Classifier
print(f'---Classifier---')
for hd in hd_cand:
  train_dataloader = Dataloader(train_dataset, batch_size=BATCH_SIZE)
  valid_dataloader = Dataloader(valid_dataset, batch_size=BATCH_SIZE)
  model = Classifier(IN_DIM, hd, OUT_DIM, device=DEVICE)
  _, ta, _, va = model.training(train_dataloader, valid_dataloader, epochs=EPOCHS, learning_rate=LR, learning_rate_decay=LR_DECAY, verbose=0)
  train_acc.append(ta); valid_acc.append(va)

plot_curves(hd_cand, train_acc, valid_acc)
# Out:
# ---Classifier---
# Training with batch_size=16, hidden_dim=32, learning_rate=0.001, learning_rate_decay=0.95
# Training with batch_size=16, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.95
# Training with batch_size=16, hidden_dim=256, learning_rate=0.001, learning_rate_decay=0.95

# %%
lr_decay_cand = [1.0, 0.95, 0.9]
train_acc = []
valid_acc = []

# Classifier
print(f'---Classifier---')
for lrd in lr_decay_cand:
  train_dataloader = Dataloader(train_dataset, batch_size=BATCH_SIZE)
  valid_dataloader = Dataloader(valid_dataset, batch_size=BATCH_SIZE)
  model = Classifier(IN_DIM, HIDEEN_DIM, OUT_DIM, device=DEVICE)
  _, ta, _, va = model.training(train_dataloader, valid_dataloader, epochs=EPOCHS, learning_rate=LR, learning_rate_decay=lrd, verbose=0)
  train_acc.append(ta); valid_acc.append(va)

plot_curves(lr_decay_cand, train_acc, valid_acc)
# Out:
# ---Classifier---
# Training with batch_size=16, hidden_dim=64, learning_rate=0.001, learning_rate_decay=1.0
# Training with batch_size=16, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.95
# Training with batch_size=16, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.9

# %% [markdown]
# ## Training with Best Hyperparameters

# %%
# Configurations
IN_DIM = np.prod(images[0].shape)
OUT_DIM = len(classes)

# %%
# Please set your hyperparameters here
EPOCHS = 200
BATCH_SIZE = 8
LR = 1e-2
LR_DECAY = 1.0
HIDEEN_DIM = 256

# %%
# Classifier
print(f'---Classifier---')
train_dataloader = Dataloader(train_dataset, batch_size=BATCH_SIZE)
valid_dataloader = Dataloader(valid_dataset, batch_size=BATCH_SIZE)
model = Classifier(IN_DIM, HIDEEN_DIM, OUT_DIM, device=DEVICE)
train_loss, train_acc, valid_loss, valid_acc = model.training(train_dataloader, valid_dataloader,epochs=EPOCHS, learning_rate=LR, learning_rate_decay=LR_DECAY)
plot_result(train_loss, train_acc, valid_loss, valid_acc)
# Out:
# ---Classifier---
# Training with batch_size=8, hidden_dim=256, learning_rate=0.01, learning_rate_decay=1.0
# Epoch 1:
# [MODEL SAVED]
# Training accuracy: 40.98%, loss: nan
# Validaion accuracy: 25.04%, loss: 5.1403
# Epoch 2:
# [MODEL SAVED]
# Training accuracy: 48.15%, loss: 1.8631
# Validaion accuracy: 26.43%, loss: 3.4802
# Epoch 3:
# [MODEL SAVED]
# Training accuracy: 47.59%, loss: 1.3105
# Validaion accuracy: 27.00%, loss: 2.0568
# Epoch 4:
# [MODEL SAVED]
# Training accuracy: 49.59%, loss: 0.8362
# Validaion accuracy: 24.71%, loss: 1.5637
# Epoch 5:
# [MODEL SAVED]
# Training accuracy: 51.60%, loss: 0.5568
# Validaion accuracy: 23.33%, loss: 1.0830
# Epoch 6:
# [MODEL SAVED]
# Training accuracy: 55.04%, loss: 0.3812
# Validaion accuracy: 23.21%, loss: 0.8269
# Epoch 7:
# [MODEL SAVED]
# Training accuracy: 56.84%, loss: 0.2882
# Validaion accuracy: 26.35%, loss: 0.5850
# Epoch 8:
# [MODEL SAVED]
# Training accuracy: 59.51%, loss: 0.2414
# Validaion accuracy: 19.74%, loss: 0.5286
# Epoch 9:
# [MODEL SAVED]
# Training accuracy: 61.23%, loss: 0.2154
# Validaion accuracy: 25.82%, loss: 0.4862
# Epoch 10:
# [MODEL SAVED]
# Training accuracy: 60.99%, loss: 0.2089
# Validaion accuracy: 24.41%, loss: 0.4841
# Epoch 11:
# [MODEL SAVED]
# Training accuracy: 61.18%, loss: 0.2000
# Validaion accuracy: 22.12%, loss: 0.4455
# Epoch 12:
# [MODEL SAVED]
# Training accuracy: 60.62%, loss: 0.1991
# Validaion accuracy: 28.05%, loss: 0.4041
# Epoch 13:
# Training accuracy: 61.08%, loss: 0.1920
# Validaion accuracy: 22.72%, loss: 0.4401
# Epoch 14:
# [MODEL SAVED]
# Training accuracy: 59.89%, loss: 0.1902
# Validaion accuracy: 23.30%, loss: 0.3959
# Epoch 15:
# Training accuracy: 60.09%, loss: 0.1886
# Validaion accuracy: 26.12%, loss: 0.4047
# Epoch 16:
# Training accuracy: 59.21%, loss: 0.1921
# Validaion accuracy: 23.62%, loss: 0.4059
# Epoch 17:
# [MODEL SAVED]
# Training accuracy: 57.90%, loss: 0.1978
# Validaion accuracy: 29.11%, loss: 0.3465
# Epoch 18:
# [MODEL SAVED]
# Training accuracy: 57.79%, loss: 0.1899
# Validaion accuracy: 26.27%, loss: 0.3420
# Epoch 19:
# Training accuracy: 57.43%, loss: 0.1902
# Validaion accuracy: 23.49%, loss: 0.3630
# Epoch 20:
# Training accuracy: 56.71%, loss: 0.1908
# Validaion accuracy: 22.75%, loss: 0.3805
# Epoch 21:
# Training accuracy: 56.60%, loss: 0.1923
# Validaion accuracy: 27.42%, loss: 0.3500
# Epoch 22:
# Training accuracy: 54.63%, loss: 0.1947
# Validaion accuracy: 23.81%, loss: 0.3559
# Epoch 23:
# [MODEL SAVED]
# Training accuracy: 54.26%, loss: 0.1957
# Validaion accuracy: 26.53%, loss: 0.3397
# Epoch 24:
# [MODEL SAVED]
# Training accuracy: 53.73%, loss: 0.1948
# Validaion accuracy: 27.93%, loss: 0.3236
# Epoch 25:
# [MODEL SAVED]
# Training accuracy: 54.06%, loss: 0.1935
# Validaion accuracy: 27.22%, loss: 0.3216
# Epoch 26:
# Training accuracy: 54.21%, loss: 0.1880
# Validaion accuracy: 24.86%, loss: 0.3226
# Epoch 27:
# Training accuracy: 53.19%, loss: 0.1954
# Validaion accuracy: 27.17%, loss: 0.3241
# Epoch 28:
# [MODEL SAVED]
# Training accuracy: 51.83%, loss: 0.1977
# Validaion accuracy: 25.73%, loss: 0.3160
# Epoch 29:
# Training accuracy: 52.33%, loss: 0.1923
# Validaion accuracy: 26.07%, loss: 0.3209
# Epoch 30:
# [MODEL SAVED]
# Training accuracy: 53.77%, loss: 0.1893
# Validaion accuracy: 29.32%, loss: 0.3117
# Epoch 31:
# [MODEL SAVED]
# Training accuracy: 52.96%, loss: 0.1923
# Validaion accuracy: 30.04%, loss: 0.2985
# Epoch 32:
# Training accuracy: 51.72%, loss: 0.1966
# Validaion accuracy: 26.64%, loss: 0.3097
# Epoch 33:
# Training accuracy: 51.53%, loss: 0.1963
# Validaion accuracy: 23.68%, loss: 0.3201
# Epoch 34:
# Training accuracy: 52.06%, loss: 0.1920
# Validaion accuracy: 26.46%, loss: 0.3289
# Epoch 35:
# Training accuracy: 50.96%, loss: 0.1943
# Validaion accuracy: 26.86%, loss: 0.3124
# Epoch 36:
# Training accuracy: 50.85%, loss: 0.1940
# Validaion accuracy: 26.91%, loss: 0.3091
# Epoch 37:
# [MODEL SAVED]
# Training accuracy: 51.75%, loss: 0.1905
# Validaion accuracy: 28.56%, loss: 0.2866
# Epoch 38:
# Training accuracy: 52.00%, loss: 0.1886
# Validaion accuracy: 28.73%, loss: 0.3068
# Epoch 39:
# Training accuracy: 52.10%, loss: 0.1906
# Validaion accuracy: 28.25%, loss: 0.3020
# Epoch 40:
# [MODEL SAVED]
# Training accuracy: 51.81%, loss: 0.1937
# Validaion accuracy: 31.78%, loss: 0.2853
# Epoch 41:
# Training accuracy: 51.92%, loss: 0.1887
# Validaion accuracy: 25.95%, loss: 0.3041
# Epoch 42:
# Training accuracy: 51.29%, loss: 0.1917
# Validaion accuracy: 28.13%, loss: 0.3027
# Epoch 43:
# Training accuracy: 51.46%, loss: 0.1899
# Validaion accuracy: 29.99%, loss: 0.2890
# Epoch 44:
# Training accuracy: 51.30%, loss: 0.1891
# Validaion accuracy: 26.92%, loss: 0.2945
# Epoch 45:
# Training accuracy: 51.94%, loss: 0.1908
# Validaion accuracy: 26.83%, loss: 0.2986
# Epoch 46:
# Training accuracy: 52.18%, loss: 0.1888
# Validaion accuracy: 23.18%, loss: 0.3190
# Epoch 47:
# Training accuracy: 52.20%, loss: 0.1868
# Validaion accuracy: 30.50%, loss: 0.3007
# Epoch 48:
# Training accuracy: 51.53%, loss: 0.1880
# Validaion accuracy: 29.04%, loss: 0.2897
# Epoch 49:
# Training accuracy: 52.34%, loss: 0.1866
# Validaion accuracy: 30.49%, loss: 0.2901
# Epoch 50:
# Training accuracy: 51.68%, loss: 0.1894
# Validaion accuracy: 26.52%, loss: 0.3026
# Epoch 51:
# Training accuracy: 51.46%, loss: 0.1901
# Validaion accuracy: 29.52%, loss: 0.2915
# Epoch 52:
# Training accuracy: 52.39%, loss: 0.1887
# Validaion accuracy: 27.26%, loss: 0.2988
# Epoch 53:
# Training accuracy: 52.76%, loss: 0.1836
# Validaion accuracy: 29.20%, loss: 0.3064
# Epoch 54:
# Training accuracy: 52.87%, loss: 0.1870
# Validaion accuracy: 24.09%, loss: 0.3094
# Epoch 55:
# Training accuracy: 52.31%, loss: 0.1870
# Validaion accuracy: 29.42%, loss: 0.2919
# Epoch 56:
# [MODEL SAVED]
# Training accuracy: 52.95%, loss: 0.1845
# Validaion accuracy: 30.37%, loss: 0.2815
# Epoch 57:
# Training accuracy: 52.25%, loss: 0.1847
# Validaion accuracy: 28.95%, loss: 0.2983
# Epoch 58:
# Training accuracy: 51.39%, loss: 0.1869
# Validaion accuracy: 28.63%, loss: 0.2886
# Epoch 59:
# [MODEL SAVED]
# Training accuracy: 51.83%, loss: 0.1875
# Validaion accuracy: 30.98%, loss: 0.2809
# Epoch 60:
# [MODEL SAVED]
# Training accuracy: 52.29%, loss: 0.1850
# Validaion accuracy: 32.02%, loss: 0.2770
# Epoch 61:
# Training accuracy: 52.59%, loss: 0.1829
# Validaion accuracy: 30.00%, loss: 0.2803
# Epoch 62:
# Training accuracy: 53.05%, loss: 0.1841
# Validaion accuracy: 30.74%, loss: 0.2940
# Epoch 63:
# Training accuracy: 53.33%, loss: 0.1845
# Validaion accuracy: 29.06%, loss: 0.2908
# Epoch 64:
# Training accuracy: 52.79%, loss: 0.1817
# Validaion accuracy: 31.42%, loss: 0.2801
# Epoch 65:
# Training accuracy: 52.17%, loss: 0.1857
# Validaion accuracy: 32.52%, loss: 0.2813
# Epoch 66:
# Training accuracy: 52.78%, loss: 0.1856
# Validaion accuracy: 28.44%, loss: 0.2918
# Epoch 67:
# Training accuracy: 52.28%, loss: 0.1844
# Validaion accuracy: 29.64%, loss: 0.2988
# Epoch 68:
# Training accuracy: 52.20%, loss: 0.1834
# Validaion accuracy: 29.19%, loss: 0.2998
# Epoch 69:
# Training accuracy: 53.11%, loss: 0.1812
# Validaion accuracy: 30.60%, loss: 0.3009
# Epoch 70:
# Training accuracy: 53.54%, loss: 0.1816
# Validaion accuracy: 29.79%, loss: 0.2859
# Epoch 71:
# Training accuracy: 53.12%, loss: 0.1834
# Validaion accuracy: 29.10%, loss: 0.2876
# Epoch 72:
# Training accuracy: 52.51%, loss: 0.1861
# Validaion accuracy: 30.86%, loss: 0.2784
# Epoch 73:
# Training accuracy: 52.60%, loss: 0.1839
# Validaion accuracy: 30.49%, loss: 0.2777
# Epoch 74:
# Training accuracy: 53.09%, loss: 0.1821
# Validaion accuracy: 28.21%, loss: 0.2905
# Epoch 75:
# Training accuracy: 52.90%, loss: 0.1824
# Validaion accuracy: 30.54%, loss: 0.2959
# Epoch 76:
# Training accuracy: 52.63%, loss: 0.1836
# Validaion accuracy: 31.09%, loss: 0.2781
# Epoch 77:
# Training accuracy: 51.91%, loss: 0.1847
# Validaion accuracy: 28.72%, loss: 0.2880
# Epoch 78:
# Training accuracy: 53.08%, loss: 0.1821
# Validaion accuracy: 28.69%, loss: 0.3123
# Epoch 79:
# Training accuracy: 53.38%, loss: 0.1819
# Validaion accuracy: 24.79%, loss: 0.3103
# Epoch 80:
# Training accuracy: 52.10%, loss: 0.1851
# Validaion accuracy: 30.27%, loss: 0.2969
# Epoch 81:
# Training accuracy: 52.49%, loss: 0.1843
# Validaion accuracy: 29.35%, loss: 0.2911
# Epoch 82:
# Training accuracy: 53.23%, loss: 0.1821
# Validaion accuracy: 30.50%, loss: 0.2838
# Epoch 83:
# Training accuracy: 53.23%, loss: 0.1820
# Validaion accuracy: 29.22%, loss: 0.2806
# Epoch 84:
# [MODEL SAVED]
# Training accuracy: 52.10%, loss: 0.1824
# Validaion accuracy: 30.51%, loss: 0.2728
# Epoch 85:
# Training accuracy: 53.79%, loss: 0.1795
# Validaion accuracy: 31.13%, loss: 0.2990
# Epoch 86:
# Training accuracy: 52.23%, loss: 0.1843
# Validaion accuracy: 29.50%, loss: 0.2940
# Epoch 87:
# Training accuracy: 53.24%, loss: 0.1834
# Validaion accuracy: 32.05%, loss: 0.2858
# Epoch 88:
# Training accuracy: 53.13%, loss: 0.1818
# Validaion accuracy: 28.95%, loss: 0.2876
# Epoch 89:
# Training accuracy: 54.37%, loss: 0.1785
# Validaion accuracy: 30.14%, loss: 0.3034
# Epoch 90:
# Training accuracy: 53.21%, loss: 0.1810
# Validaion accuracy: 27.82%, loss: 0.3078
# Epoch 91:
# [MODEL SAVED]
# Training accuracy: 54.16%, loss: 0.1784
# Validaion accuracy: 30.67%, loss: 0.2712
# Epoch 92:
# Training accuracy: 52.89%, loss: 0.1824
# Validaion accuracy: 30.23%, loss: 0.2982
# Epoch 93:
# Training accuracy: 54.48%, loss: 0.1770
# Validaion accuracy: 31.16%, loss: 0.2813
# Epoch 94:
# Training accuracy: 52.17%, loss: 0.1830
# Validaion accuracy: 30.39%, loss: 0.2911
# Epoch 95:
# Training accuracy: 52.98%, loss: 0.1805
# Validaion accuracy: 31.93%, loss: 0.2723
# Epoch 96:
# Training accuracy: 52.79%, loss: 0.1812
# Validaion accuracy: 32.01%, loss: 0.2812
# Epoch 97:
# [MODEL SAVED]
# Training accuracy: 52.80%, loss: 0.1806
# Validaion accuracy: 34.47%, loss: 0.2655
# Epoch 98:
# Training accuracy: 52.77%, loss: 0.1810
# Validaion accuracy: 30.42%, loss: 0.2699
# Epoch 99:
# Training accuracy: 54.36%, loss: 0.1780
# Validaion accuracy: 30.38%, loss: 0.2950
# Epoch 100:
# Training accuracy: 53.23%, loss: 0.1800
# Validaion accuracy: 29.82%, loss: 0.2877
# Epoch 101:
# Training accuracy: 53.12%, loss: 0.1826
# Validaion accuracy: 30.28%, loss: 0.2678
# Epoch 102:
# Training accuracy: 54.36%, loss: 0.1761
# Validaion accuracy: 29.18%, loss: 0.2864
# Epoch 103:
# Training accuracy: 55.50%, loss: 0.1722
# Validaion accuracy: 33.43%, loss: 0.2793
# Epoch 104:
# Training accuracy: 54.08%, loss: 0.1782
# Validaion accuracy: 29.97%, loss: 0.2844
# Epoch 105:
# Training accuracy: 54.50%, loss: 0.1755
# Validaion accuracy: 33.18%, loss: 0.2759
# Epoch 106:
# Training accuracy: 53.27%, loss: 0.1792
# Validaion accuracy: 31.25%, loss: 0.2766
# Epoch 107:
# Training accuracy: 54.68%, loss: 0.1778
# Validaion accuracy: 30.50%, loss: 0.2973
# Epoch 108:
# Training accuracy: 53.51%, loss: 0.1794
# Validaion accuracy: 30.89%, loss: 0.2837
# Epoch 109:
# Training accuracy: 52.85%, loss: 0.1803
# Validaion accuracy: 32.05%, loss: 0.2739
# Epoch 110:
# Training accuracy: 54.01%, loss: 0.1784
# Validaion accuracy: 32.88%, loss: 0.2800
# Epoch 111:
# Training accuracy: 53.53%, loss: 0.1802
# Validaion accuracy: 31.04%, loss: 0.2775
# Epoch 112:
# Training accuracy: 53.05%, loss: 0.1783
# Validaion accuracy: 28.78%, loss: 0.3035
# Epoch 113:
# Training accuracy: 53.74%, loss: 0.1764
# Validaion accuracy: 30.07%, loss: 0.2801
# Epoch 114:
# Training accuracy: 54.38%, loss: 0.1768
# Validaion accuracy: 30.83%, loss: 0.2791
# Epoch 115:
# Training accuracy: 54.61%, loss: 0.1758
# Validaion accuracy: 29.72%, loss: 0.2838
# Epoch 116:
# Training accuracy: 54.50%, loss: 0.1772
# Validaion accuracy: 31.72%, loss: 0.2747
# Epoch 117:
# Training accuracy: 54.18%, loss: 0.1784
# Validaion accuracy: 31.02%, loss: 0.2804
# Epoch 118:
# Training accuracy: 54.79%, loss: 0.1766
# Validaion accuracy: 33.32%, loss: 0.2695
# Epoch 119:
# Training accuracy: 54.20%, loss: 0.1768
# Validaion accuracy: 28.41%, loss: 0.3153
# Epoch 120:
# Training accuracy: 53.61%, loss: 0.1803
# Validaion accuracy: 31.66%, loss: 0.2705
# Epoch 121:
# Training accuracy: 55.40%, loss: 0.1733
# Validaion accuracy: 32.26%, loss: 0.2795
# Epoch 122:
# Training accuracy: 55.12%, loss: 0.1735
# Validaion accuracy: 27.62%, loss: 0.2975
# Epoch 123:
# Training accuracy: 54.72%, loss: 0.1734
# Validaion accuracy: 32.00%, loss: 0.3014
# Epoch 124:
# Training accuracy: 54.61%, loss: 0.1771
# Validaion accuracy: 29.43%, loss: 0.2996
# Epoch 125:
# Training accuracy: 54.09%, loss: 0.1778
# Validaion accuracy: 32.09%, loss: 0.2789
# Epoch 126:
# Training accuracy: 55.11%, loss: 0.1751
# Validaion accuracy: 29.17%, loss: 0.2871
# Epoch 127:
# Training accuracy: 55.08%, loss: 0.1725
# Validaion accuracy: 30.20%, loss: 0.2880
# Epoch 128:
# Training accuracy: 55.74%, loss: 0.1703
# Validaion accuracy: 31.06%, loss: 0.2704
# Epoch 129:
# Training accuracy: 54.47%, loss: 0.1740
# Validaion accuracy: 30.26%, loss: 0.2815
# Epoch 130:
# Training accuracy: 54.78%, loss: 0.1744
# Validaion accuracy: 29.64%, loss: 0.2916
# Epoch 131:
# Training accuracy: 54.76%, loss: 0.1752
# Validaion accuracy: 33.87%, loss: 0.2663
# Epoch 132:
# Training accuracy: 55.11%, loss: 0.1724
# Validaion accuracy: 30.88%, loss: 0.2829
# Epoch 133:
# Training accuracy: 54.24%, loss: 0.1768
# Validaion accuracy: 29.34%, loss: 0.3026
# Epoch 134:
# Training accuracy: 55.21%, loss: 0.1731
# Validaion accuracy: 32.75%, loss: 0.2746
# Epoch 135:
# Training accuracy: 53.93%, loss: 0.1775
# Validaion accuracy: 34.39%, loss: 0.2686
# Epoch 136:
# Training accuracy: 53.93%, loss: 0.1768
# Validaion accuracy: 32.57%, loss: 0.2667
# Epoch 137:
# Training accuracy: 55.40%, loss: 0.1734
# Validaion accuracy: 32.48%, loss: 0.2827
# Epoch 138:
# Training accuracy: 56.20%, loss: 0.1690
# Validaion accuracy: 31.12%, loss: 0.2876
# Epoch 139:
# Training accuracy: 56.33%, loss: 0.1692
# Validaion accuracy: 32.07%, loss: 0.2714
# Epoch 140:
# Training accuracy: 54.93%, loss: 0.1747
# Validaion accuracy: 32.05%, loss: 0.2678
# Epoch 141:
# Training accuracy: 54.86%, loss: 0.1729
# Validaion accuracy: 33.73%, loss: 0.2703
# Epoch 142:
# Training accuracy: 53.82%, loss: 0.1746
# Validaion accuracy: 32.01%, loss: 0.2724
# Epoch 143:
# Training accuracy: 54.88%, loss: 0.1749
# Validaion accuracy: 29.58%, loss: 0.2991
# Epoch 144:
# Training accuracy: 55.34%, loss: 0.1724
# Validaion accuracy: 30.74%, loss: 0.2859
# Epoch 145:
# Training accuracy: 53.86%, loss: 0.1767
# Validaion accuracy: 28.54%, loss: 0.3071
# Epoch 146:
# Training accuracy: 55.20%, loss: 0.1720
# Validaion accuracy: 31.94%, loss: 0.2780
# Epoch 147:
# Training accuracy: 55.53%, loss: 0.1718
# Validaion accuracy: 30.80%, loss: 0.2935
# Epoch 148:
# Training accuracy: 54.95%, loss: 0.1741
# Validaion accuracy: 33.36%, loss: 0.2677
# Epoch 149:
# Training accuracy: 55.20%, loss: 0.1723
# Validaion accuracy: 32.13%, loss: 0.2863
# Epoch 150:
# Training accuracy: 54.45%, loss: 0.1733
# Validaion accuracy: 30.69%, loss: 0.2852
# Epoch 151:
# Training accuracy: 54.61%, loss: 0.1744
# Validaion accuracy: 31.78%, loss: 0.2685
# Epoch 152:
# Training accuracy: 56.40%, loss: 0.1721
# Validaion accuracy: 32.65%, loss: 0.2793
# Epoch 153:
# Training accuracy: 55.46%, loss: 0.1710
# Validaion accuracy: 31.63%, loss: 0.2763
# Epoch 154:
# Training accuracy: 54.95%, loss: 0.1709
# Validaion accuracy: 32.50%, loss: 0.2789
# Epoch 155:
# Training accuracy: 54.95%, loss: 0.1765
# Validaion accuracy: 31.88%, loss: 0.2757
# Epoch 156:
# Training accuracy: 56.79%, loss: 0.1709
# Validaion accuracy: 25.68%, loss: 0.3115
# Epoch 157:
# [MODEL SAVED]
# Training accuracy: 55.00%, loss: 0.1718
# Validaion accuracy: 33.06%, loss: 0.2651
# Epoch 158:
# Training accuracy: 55.65%, loss: 0.1733
# Validaion accuracy: 30.67%, loss: 0.2785
# Epoch 159:
# Training accuracy: 56.24%, loss: 0.1694
# Validaion accuracy: 30.86%, loss: 0.2770
# Epoch 160:
# Training accuracy: 55.87%, loss: 0.1708
# Validaion accuracy: 33.23%, loss: 0.2890
# Epoch 161:
# Training accuracy: 55.89%, loss: 0.1710
# Validaion accuracy: 31.64%, loss: 0.2731
# Epoch 162:
# Training accuracy: 56.23%, loss: 0.1698
# Validaion accuracy: 34.61%, loss: 0.2729
# Epoch 163:
# Training accuracy: 55.14%, loss: 0.1728
# Validaion accuracy: 31.09%, loss: 0.2932
# Epoch 164:
# Training accuracy: 56.26%, loss: 0.1706
# Validaion accuracy: 31.01%, loss: 0.2785
# Epoch 165:
# Training accuracy: 55.50%, loss: 0.1698
# Validaion accuracy: 32.16%, loss: 0.2776
# Epoch 166:
# Training accuracy: 55.51%, loss: 0.1709
# Validaion accuracy: 31.72%, loss: 0.2922
# Epoch 167:
# Training accuracy: 55.35%, loss: 0.1724
# Validaion accuracy: 31.36%, loss: 0.2797
# Epoch 168:
# Training accuracy: 55.49%, loss: 0.1710
# Validaion accuracy: 32.16%, loss: 0.2752
# Epoch 169:
# Training accuracy: 56.31%, loss: 0.1693
# Validaion accuracy: 29.05%, loss: 0.2918
# Epoch 170:
# Training accuracy: 56.37%, loss: 0.1685
# Validaion accuracy: 31.21%, loss: 0.2724
# Epoch 171:
# Training accuracy: 55.38%, loss: 0.1739
# Validaion accuracy: 32.66%, loss: 0.2710
# Epoch 172:
# Training accuracy: 55.49%, loss: 0.1728
# Validaion accuracy: 33.44%, loss: 0.2692
# Epoch 173:
# Training accuracy: 55.33%, loss: 0.1713
# Validaion accuracy: 30.92%, loss: 0.2706
# Epoch 174:
# Training accuracy: 55.66%, loss: 0.1700
# Validaion accuracy: 32.24%, loss: 0.2802
# Epoch 175:
# Training accuracy: 56.12%, loss: 0.1694
# Validaion accuracy: 31.16%, loss: 0.2733
# Epoch 176:
# Training accuracy: 55.76%, loss: 0.1698
# Validaion accuracy: 31.96%, loss: 0.2716
# Epoch 177:
# Training accuracy: 54.71%, loss: 0.1742
# Validaion accuracy: 31.44%, loss: 0.2675
# Epoch 178:
# [MODEL SAVED]
# Training accuracy: 56.79%, loss: 0.1681
# Validaion accuracy: 35.10%, loss: 0.2533
# Epoch 179:
# Training accuracy: 57.02%, loss: 0.1672
# Validaion accuracy: 30.78%, loss: 0.3056
# Epoch 180:
# Training accuracy: 56.32%, loss: 0.1695
# Validaion accuracy: 32.38%, loss: 0.2761
# Epoch 181:
# Training accuracy: 55.04%, loss: 0.1707
# Validaion accuracy: 33.43%, loss: 0.2603
# Epoch 182:
# Training accuracy: 56.03%, loss: 0.1704
# Validaion accuracy: 31.10%, loss: 0.2779
# Epoch 183:
# Training accuracy: 55.67%, loss: 0.1704
# Validaion accuracy: 33.14%, loss: 0.2699
# Epoch 184:
# Training accuracy: 55.15%, loss: 0.1711
# Validaion accuracy: 31.38%, loss: 0.2809
# Epoch 185:
# Training accuracy: 55.65%, loss: 0.1706
# Validaion accuracy: 30.53%, loss: 0.2797
# Epoch 186:
# Training accuracy: 54.97%, loss: 0.1714
# Validaion accuracy: 31.93%, loss: 0.2728
# Epoch 187:
# Training accuracy: 54.86%, loss: 0.1704
# Validaion accuracy: 31.52%, loss: 0.2858
# Epoch 188:
# Training accuracy: 55.81%, loss: 0.1702
# Validaion accuracy: 33.18%, loss: 0.2666
# Epoch 189:
# Training accuracy: 56.35%, loss: 0.1699
# Validaion accuracy: 33.83%, loss: 0.2783
# Epoch 190:
# Training accuracy: 55.60%, loss: 0.1720
# Validaion accuracy: 30.26%, loss: 0.2816
# Epoch 191:
# Training accuracy: 57.12%, loss: 0.1683
# Validaion accuracy: 31.25%, loss: 0.2833
# Epoch 192:
# Training accuracy: 56.72%, loss: 0.1679
# Validaion accuracy: 33.80%, loss: 0.2943
# Epoch 193:
# Training accuracy: 57.02%, loss: 0.1672
# Validaion accuracy: 34.83%, loss: 0.2774
# Epoch 194:
# Training accuracy: 56.89%, loss: 0.1675
# Validaion accuracy: 33.13%, loss: 0.2727
# Epoch 195:
# Training accuracy: 55.02%, loss: 0.1723
# Validaion accuracy: 33.65%, loss: 0.2817
# Epoch 196:
# Training accuracy: 55.96%, loss: 0.1688
# Validaion accuracy: 33.06%, loss: 0.2800
# Epoch 197:
# Training accuracy: 55.43%, loss: 0.1708
# Validaion accuracy: 32.70%, loss: 0.2855
# Epoch 198:
# Training accuracy: 56.88%, loss: 0.1702
# Validaion accuracy: 31.34%, loss: 0.2788
# Epoch 199:
# Training accuracy: 54.90%, loss: 0.1724
# Validaion accuracy: 33.05%, loss: 0.2650
# Epoch 200:
# Training accuracy: 56.87%, loss: 0.1680
# Validaion accuracy: 34.18%, loss: 0.2669

# %% [markdown]
# Test the model with test_dataset. <font color='red'>The test accuracy must reach at least 28%.</font>

# %%
test_dataloader = Dataloader(test_dataset)
model.load_model(MODEL_PATH)
model.test(test_dataloader)
# Out:
# Got 3399 correct prediction in 10000 test data, accuracy: 33.99%
